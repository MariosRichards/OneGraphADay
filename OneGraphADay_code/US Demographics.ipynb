# %%
# https://dev.socrata.com/foundry/data.cdc.gov/pzzm-ur7y

# timer on when the dataset was loaded 23:30

# %%
# What do we want to do with the data?
# "I have one on US demographics. What is the current and projected birth rate for whites, blacks, and latinos?"
# "As it will shape our politics in the future these numbers are very important."

# So, time series plot of birth rate
# fit basic models to time series so you can project

# if we can get population distribution at start of series, we can use that to get an approx (minus imm/emm)
# population change projection
# oh, wait - we don't have the death rates!

# %%
#!/usr/bin/env python

# make sure to install these packages before running:
# pip install pandas
# pip install bokeh

import numpy as np
import pandas as pd
import datetime
import urllib
 

from collections import OrderedDict

query = ("https://data.cdc.gov/resource/pzzm-ur7y.json")
raw_data = pd.read_json(query)

# %%
import statsmodels.api as sm
# import matplotlib.pyplot as plt
import seaborn as sns
# sns.set(style="ticks", color_codes=True)
# Out:
# C:\ANACON~1\envs\OneGraphADay\lib\site-packages\statsmodels\compat\pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools

# %%
# from bokeh.plotting import *
# from bokeh.models import HoverTool

# %%
raw_data
# Out:
#      birth_rate  fertility_rate  live_births                    race  year
# 0          19.9            73.2        74355  Asian/Pacific Islander  1980
# 1          20.1            73.7        84553  Asian/Pacific Islander  1981
# 2          20.3            74.8        93193  Asian/Pacific Islander  1982
# 3          19.5            71.7        95713  Asian/Pacific Islander  1983
# 4          18.8            69.2        98926  Asian/Pacific Islander  1984
# 5          18.7            68.4       104606  Asian/Pacific Islander  1985
# 6          18.0            66.0       107797  Asian/Pacific Islander  1986
# 7          18.4            67.1       116560  Asian/Pacific Islander  1987
# 8          19.2            70.2       129035  Asian/Pacific Islander  1988
# 9          18.7            68.2       133075  Asian/Pacific Islander  1989
# 10         19.0            69.6       141635  Asian/Pacific Islander  1990
# ...

# %%
sns.tsplot(raw_data, time="year", unit ="race", value="fertility_rate" );

# %%
import numpy as np; np.random.seed(22)
import seaborn as sns; sns.set(color_codes=True)
x = np.linspace(0, 15, 31)
data = np.sin(x) + np.random.rand(10, 31) + np.random.randn(10, 1)
ax = sns.tsplot(data=data)
